# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %%
inner_merge = a_df.merge(b_df, on='Country')
inner_merge
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %%
left_merge = a_df.merge(b_df, on='Country', how='left')
left_merge
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %%
right_merge = a_df.merge(b_df, on='Country', how='right')
right_merge
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %%
outer_merged_df = a_df.merge(b_df, on='Country', how='outer')
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %%
countries_df = pd.read_csv("dictionary.csv")
countries_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
summer_df = pd.read_csv("summer.csv")
summer_df.sort_values(by="Country", ascending=True)
# Out:
#        Year         City          Sport           Discipline  \
# 30929  2012       London      Taekwondo            Taekwondo
# 28965  2008      Beijing      Taekwondo            Taekwondo
# 19323  1988        Seoul        Sailing              Sailing
# 17060  1984  Los Angeles         Boxing               Boxing
# 23624  2000       Sydney      Athletics            Athletics
# 23631  2000       Sydney      Athletics            Athletics
# 17064  1984  Los Angeles         Boxing               Boxing
# 20200  1992    Barcelona         Boxing               Boxing
# 28637  2008      Beijing           Judo                 Judo
# 28602  2008      Beijing           Judo                 Judo
# 23655  2000       Sydney      Athletics            Athletics
# 23536  2000       Sydney      Athletics            Athletics
# 23890  2000       Sydney         Boxing               Boxing
# 29600  2012       London      Athletics            Athletics
# 21610  1996      Atlanta      Athletics            Athletics
# 21960  1996      Atlanta         Boxing               Boxing
# 19874  1992    Barcelona      Athletics            Athletics
# 21946  1996      Atlanta         Boxing               Boxing
# 1957   1912    Stockholm       Aquatics             Swimming
# 1956   1912    Stockholm       Aquatics             Swimming
# 1208   1908       London      Athletics            Athletics
# 1967   1912    Stockholm       Aquatics             Swimming
# 1154   1908       London       Aquatics             Swimming
# 1987   1912    Stockholm       Aquatics             Swimming
# 1954   1912    Stockholm       Aquatics             Swimming
# 2785   1912    Stockholm         Tennis               Tennis
# 1989   1912    Stockholm       Aquatics             Swimming
# 1298   1908       London         Boxing               Boxing
# 1986   1912    Stockholm       Aquatics             Swimming
# 1988   1912    Stockholm       Aquatics             Swimming
# ...     ...          ...            ...                  ...
# 132    1896       Athens         Tennis               Tennis
# 257    1900        Paris      Athletics            Athletics
# 261    1900        Paris      Athletics            Athletics
# 769    1904     St Louis      Athletics            Athletics
# 767    1904     St Louis      Athletics            Athletics
# 493    1900        Paris         Rowing               Rowing
# 428    1900        Paris           Polo                 Polo
# 494    1900        Paris         Rowing               Rowing
# 866    1904     St Louis        Fencing              Fencing
# 495    1900        Paris         Rowing               Rowing
# 865    1904     St Louis        Fencing              Fencing
# 864    1904     St Louis        Fencing              Fencing
# 768    1904     St Louis      Athletics            Athletics
# 429    1900        Paris           Polo                 Polo
# 430    1900        Paris           Polo                 Polo
# 433    1900        Paris           Polo                 Polo
# 432    1900        Paris           Polo                 Polo
# 431    1900        Paris           Polo                 Polo
# 766    1904     St Louis      Athletics            Athletics
# 765    1904     St Louis      Athletics            Athletics
# 427    1900        Paris           Polo                 Polo
# 426    1900        Paris           Polo                 Polo
# 259    1900        Paris      Athletics            Athletics
# 258    1900        Paris      Athletics            Athletics
# 424    1900        Paris           Polo                 Polo
# 423    1900        Paris           Polo                 Polo
# 29603  2012       London      Athletics            Athletics
# 31072  2012       London  Weightlifting        Weightlifting
# 31091  2012       London  Weightlifting        Weightlifting
# 31110  2012       London      Wrestling  Wrestling Freestyle
#
#                                 Athlete Country Gender  \
# 30929                  NIKPAI, Rohullah     AFG    Men
# 28965                  NIKPAI, Rohullah     AFG    Men
# 19323                   BOERSMA, Jan D.     AHO    Men
# 17060                    ZAOUI, Mohamed     ALG    Men
# 23624                   SAIDI-SIEF, Ali     ALG    Men
# 23631               SAID GUERNI, Djabir     ALG    Men
# 17064                  MOUSSA, Mustapha     ALG    Men
# 20200                   SOLTANI, Hocine     ALG    Men
# 28637                   BENIKHLEF, Amar     ALG    Men
# 28602                    HADDAD, Soraya     ALG  Women
# 23655              HAMMAD, Abderrahmane     ALG    Men
# 23536              MERAH-BENIDA, Nouria     ALG  Women
# 23890                  ALLALOU, Mohamed     ALG    Men
# 29600                MAKHLOUFI, Taoufik     ALG    Men
# 21610               MORCELI, Nourredine     ALG    Men
# 21960                   BAHARI, Mohamed     ALG    Men
# 19874                BOULMERKA, Hassiba     ALG  Women
# 21946                   SOLTANI, Hocine     ALG    Men
# 1957                  WYLIE, Wilhelmina     ANZ  Women
# 1956                      DURACK, Fanny     ANZ  Women
# 1208                     KERR, Harry E.     ANZ    Men
# 1967                HARDWICK, Harold H.     ANZ    Men
# 1154              BEAUREPAIRE, Frank E.     ANZ    Men
# 1987                  CHAMPION, Malcolm     ANZ    Men
# 1954                       HEALY, Cecil     ANZ    Men
# 2785         WILDING, Anthony Frederick     ANZ    Men
# 1989                       HEALY, Cecil     ANZ    Men
# 1298                 BAKER, Reginald L.     ANZ    Men
# 1986                   BOARDMAN, Leslie     ANZ    Men
# 1988                HARDWICK, Harold H.     ANZ    Men
# ...                                 ...     ...    ...
# 132                        FLACK, Edwin     ZZX    Men
# 257                    BENNETT, Charles     ZZX    Men
# 261                       TYSOE, Alfred     ZZX    Men
# 769               VERNER, William Frank     ZZX    Men
# 767                        HEARN, Lacey     ZZX    Men
# 493            BRANDT, Francois Antoine     ZZX    Men
# 428                   MACKEY, Frank Jay     ZZX    Men
# 494        BROCKMANN, Hermanus Gerardus     ZZX    Men
# 866              VAN ZO POST, Albertson     ZZX    Men
# 495                       KLEIN, Roelof     ZZX    Men
# 865                        FONST, Ramon     ZZX    Men
# 864                        DIAZ, Manuel     ZZX    Men
# 768                    LIGHTBODY, James     ZZX    Men
# 429                   RAWLINSON, Alfred     ZZX    Men
# 430            BUCKMASTER, Walter Selby     ZZX    Men
# 433             MCCREERY, Walter Adolph     ZZX    Men
# 432          FREAKE, Frederick Maitland     ZZX    Men
# 431    COMTE DE MADRE, José Pierre M.J.     ZZX    Men
# 766                       HATCH, Sidney     ZZX    Men
# 765                       CORAY, Albert     ZZX    Men
# 427               KEENE, Foxhall Parker     ZZX    Men
# 426                        DALY, Dennis     ZZX    Men
# 259                    ROBINSON, Sidney     ZZX    Men
# 258                        RIMMER, John     ZZX    Men
# 424                FAUQUET LEMAITRE, A.     ZZX    Men
# 423              DUC DE BISACCIA, Louis     ZZX    Men
# 29603                           Pending     NaN  Women
# 31072                           Pending     NaN  Women
# 31091                           Pending     NaN    Men
# 31110                   KUDUKHOV, Besik     NaN    Men
#
#                                      Event   Medal
# 30929                           58 - 68 KG  Bronze
# 28965                              - 58 KG  Bronze
# 19323                  Board (Division Ii)  Silver
# 17060                              71-75KG  Bronze
# 23624                                5000M  Silver
# 23631                                 800M  Bronze
# 17064        75 - 81KG (Light-Heavyweight)  Bronze
# 20200            54 - 57KG (Featherweight)  Bronze
# 28637             81 - 90KG (Middleweight)  Silver
# 28602         48 - 52KG (Half-Lightweight)  Bronze
# 23655                            High Jump  Bronze
# 23536                                1500M    Gold
# 23890     60 - 63.5KG (Light-Welterweight)  Bronze
# 29600                                1500M    Gold
# 21610                                1500M    Gold
# 21960                              71-75KG  Bronze
# 19874                                1500M    Gold
# 21946              57 - 60KG (Lightweight)    Gold
# 1957                        100M Freestyle  Silver
# 1956                        100M Freestyle    Gold
# 1208                            3500M Walk  Bronze
# 1967                        400M Freestyle  Bronze
# 1154                        400M Freestyle  Silver
# 1987                4X200M Freestyle Relay    Gold
# 1954                        100M Freestyle  Silver
# 2785                        Singles Indoor  Bronze
# 1989                4X200M Freestyle Relay    Gold
# 1298         63.5 - 71.67KG (Middleweight)  Silver
# 1986                4X200M Freestyle Relay    Gold
# 1988                4X200M Freestyle Relay    Gold
# ...                                    ...     ...
# 132                                Doubles  Bronze
# 257                             5000M Team    Gold
# 261                             5000M Team    Gold
# 769                            4Miles Team  Silver
# 767                            4Miles Team  Silver
# 493    Pair-Oared Shell With Coxswain (2+)    Gold
# 428                                   Polo    Gold
# 494    Pair-Oared Shell With Coxswain (2+)    Gold
# 866                              Foil Team    Gold
# 495    Pair-Oared Shell With Coxswain (2+)    Gold
# 865                              Foil Team    Gold
# 864                              Foil Team    Gold
# 768                            4Miles Team  Silver
# 429                                   Polo    Gold
# 430                                   Polo  Silver
# 433                                   Polo  Silver
# 432                                   Polo  Silver
# 431                                   Polo  Silver
# 766                            4Miles Team  Silver
# 765                            4Miles Team  Silver
# 427                                   Polo    Gold
# 426                                   Polo    Gold
# 259                             5000M Team    Gold
# 258                             5000M Team    Gold
# 424                                   Polo  Bronze
# 423                                   Polo  Bronze
# 29603                                1500M    Gold
# 31072                                 63KG    Gold
# 31091                                 94KG  Silver
# 31110                             Wf 60 KG  Silver
#
# [31165 rows x 9 columns]
